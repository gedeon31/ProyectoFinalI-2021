# %% [markdown]
# #                          Datos bursátiles del S&P 500
#
# ### Datos bursátiles históricos de todas las empresas actuales del S&P 500
#
# **INTRODUCCION**
#
# Los datos del mercado de valores pueden ser interesantes de analizar y como incentivo adicional, los modelos
# predictivos sólidos pueden tener grandes beneficios financieros. La cantidad de datos financieros en la web
# parece no tener fin. Un conjunto de datos grande y bien estructurado sobre una amplia gama de empresas
# puede ser difícil de conseguir. Aquí proporciono un conjunto de datos con precios de acciones históricos
# (últimos 5 años) para todas las empresas que se encuentran actualmente en el índice S&P 500.
#
# **CONTENIDO**
#
# Los datos se presentan en un par de formatos para adaptarse a las necesidades o limitaciones computacionales de diferentes individuos. He incluido archivos que contienen 5 años de datos de stock.
#
# La carpeta individual_stocks_5yr contiene archivos de datos para acciones individuales, etiquetados por su nombre de cotización de acciones. All_stocks_5yr.csv contiene los mismos datos de todas las empresas.
#
# Todos los archivos tienen las siguientes columnas:
#
# * Fecha(**Date**) - en formato: aa-mm-dd
# * Apertura (**Open**): precio de la acción en la apertura del mercado (estos son datos de NYSE, por lo que todo en USD)
# * Alto(**High** ): precio más alto alcanzado en el día Cierre.
# * Cierre(**Close**): precio de la acción en el cierre del mercado
# * bajo(**Low**): precio más bajo alcanzado en el día
# * Volumen(**Volume**): número de acciones negociadas
# * Nombre(**Name**): el nombre de cotización de la acción

# %% [markdown]
# ![apple.png](attachment:apple.png)

# %%
# Importamos todas las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importamos el dataset para iniciar el análisis
df = pd.read_csv('../input/sp-500-sctok/sp500.csv') 
#Visualizamos los primeros 5 datos del dataset
print(df.head())
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
df
# Out:
#              date     open     high      low    close     volume  Name
# 0      2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1      2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2      2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3      2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4      2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# ...           ...      ...      ...      ...      ...        ...   ...
# 21024  2018-02-01  31.7500  32.2800  31.5975  32.0600    2256601   NFX
# 21025  2018-02-02  31.6600  31.8700  30.3100  30.3600    3736398   NFX
# 21026  2018-02-05  30.0000  30.6400  29.2800  29.4100    4250786   NFX
# 21027  2018-02-06  28.9000  30.1300  28.6500  29.6400    3701765   NFX
# 21028  2018-02-07  29.5700  29.9300  28.4600  28.5300    3800172   NFX
#
# [21029 rows x 7 columns]

# %% [markdown]
# # ANALIZAMOS LOS DATOS
# **Análizamos los datos que tenemos disponibles**

# %%
print('Información del dataset:')
print(df.info())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21029 entries, 0 to 21028
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    21029 non-null  object
#  1   open    21029 non-null  float64
#  2   high    21029 non-null  float64
#  3   low     21029 non-null  float64
#  4   close   21029 non-null  float64
#  5   volume  21029 non-null  int64
#  6   Name    21029 non-null  object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.1+ MB
# None

# %%
print('Descripción del dataset:')
print(df.describe())
# Out:
# Descripción del dataset:
#                open          high           low         close        volume
# count  21029.000000  21029.000000  21029.000000  21029.000000  2.102900e+04
# mean     139.242633    140.445383    137.960533    139.245234  1.172427e+07
# std      208.486812    209.963659    206.864863    208.497995  1.934414e+07
# min       17.510000     17.930000     17.405000     17.530000  7.932000e+03
# 25%       36.970000     37.420000     36.550000     36.950000  1.600984e+06
# 50%       57.260000     57.750000     56.690000     57.250000  3.808013e+06
# 75%      125.050000    126.150000    123.700000    124.900000  1.379598e+07
# max     1188.000000   1198.000000   1184.060000   1187.560000  3.653806e+08

# %%
print('Distribución de las compañias del grupo S&P 500 stock:')
print(df.groupby('Name').size())
# Out:
# Distribución de las compañias del grupo S&P 500 stock:
# Name
# AAP      1259
# AAPL     1259
# ESS      1259
# FAST     1259
# FB       1259
# FL       1259
# FOX      1169
# GM       1259
# GOOG      975
# GOOGL    1259
# M        1259
# MS       1259
# MSFT     1259
# MSI      1259
# MYL      1259
# NFLX     1259
# NFX      1259
# dtype: int64

# %%
df.shape
# Out:
# (21029, 7)

# %%
df.tail()
# Out:
#              date   open   high      low  close   volume Name
# 21024  2018-02-01  31.75  32.28  31.5975  32.06  2256601  NFX
# 21025  2018-02-02  31.66  31.87  30.3100  30.36  3736398  NFX
# 21026  2018-02-05  30.00  30.64  29.2800  29.41  4250786  NFX
# 21027  2018-02-06  28.90  30.13  28.6500  29.64  3701765  NFX
# 21028  2018-02-07  29.57  29.93  28.4600  28.53  3800172  NFX

# %%
import matplotlib.pyplot as plt
#Grafico Alsista Bajista - apertura vs cierre
fig = df[df.Name == 'AAPL'].plot(kind='scatter', 
          x='open', y='close', color='blue', label='Apple')
df[df.Name == 'MSFT'].plot(kind='scatter', 
    x='open', y='close', color='green', label='Microsoft Corp', ax=fig)
df[df.Name == 'FB'].plot(kind='scatter', 
    x='open', y='close', color='red', label='Facebook Inc A', ax=fig)
fig.set_xlabel('Alsista Bajista - Open')
fig.set_ylabel('Alsista Bajista - Close')
fig.set_title('Alsista Bajista - Open Vs Close')
plt.show()

# %%
#Grafico Minimo-Maximo - alto vs bajo
fig = df[df.Name == 'AAPL'].plot(kind='scatter', 
          x='high', y='low', color='blue', label='Apple')
df[df.Name == 'MSFT'].plot(kind='scatter', 
    x='high', y='low', color='green', label='Microsoft Corp', ax=fig)
df[df.Name == 'FB'].plot(kind='scatter', 
    x='high', y='low', color='red', label='Facebook Inc A', ax=fig)
fig.set_xlabel('Minimo-Maximo - High')
fig.set_ylabel('Minimo-Maximo - Low')
fig.set_title('Minimo-Maximo - High Vs Low')
plt.show()

# %% [markdown]
# # PREPROCESAMIENTO DE DATOS

# %%
df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
# Definimos las variables independiente y dependientes

#Separacion de todos los datos con las características y las etiquetas o resultados
#X = np.array(df.drop(['Name'], 1))
#print("X=",X)
#y = np.array(df['Name'])
#print("y=",y) 

X = df.iloc[:, :6].values
y = df.iloc[:, 6].values
print(X)
print(y)
# Out:
# [['2013-02-08' 67.7142 68.4014 66.8928 67.8542 158168416]
#  ['2013-02-11' 68.0714 69.2771 67.6071 68.5614 129029425]
#  ['2013-02-12' 68.5014 68.9114 66.8205 66.8428 151829363]
#  ...
#  ['2018-02-05' 30.0 30.64 29.28 29.41 4250786]
#  ['2018-02-06' 28.9 30.13 28.65 29.64 3701765]
#  ['2018-02-07' 29.57 29.93 28.46 28.53 3800172]]
# ['AAPL' 'AAPL' 'AAPL' ... 'NFX' 'NFX' 'NFX']

# %%
# Imputacion de datos faltantes
# corrige los datos con "nan" con medias de los datos

from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan, strategy='mean')

imp = imp.fit(X[:,1:6])
X[:, 1:6] = imp.transform(X[:, 1:6])

print(X,y)
# Out:
# [['2013-02-08' 67.7142 68.4014 66.8928 67.8542 158168416.0]
#  ['2013-02-11' 68.0714 69.2771 67.6071 68.5614 129029425.0]
#  ['2013-02-12' 68.5014 68.9114 66.8205 66.8428 151829363.0]
#  ...
#  ['2018-02-05' 30.0 30.64 29.28 29.41 4250786.0]
#  ['2018-02-06' 28.9 30.13 28.65 29.64 3701765.0]
#  ['2018-02-07' 29.57 29.93 28.46 28.53 3800172.0]] ['AAPL' 'AAPL' 'AAPL' ... 'NFX' 'NFX' 'NFX']

# %%
df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
abertura = df['open'].mean()
alto=df['high'].mean()
bajo=df['low'].mean()
df['open'].fillna(abertura, inplace=True)
df['high'].fillna(alto, inplace=True)
df['low'].fillna(bajo, inplace=True)

# %%
df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
df.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
# vamos a resolver los datos categoricos de la columna datos
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
X[:, 0]=labelencoder_x.fit_transform(X[:, 0])
#  vamos a resolver Datos categoricos de la columna NAME
#labelencoder_y= LabelEncoder()
#y=labelencoder_y.fit_transform(y)

print("X[:, 0]=",X[:, 0])
print("X=",X)
print("y=",y)
# Out:
# X[:, 0]= [0 1 2 ... 1256 1257 1258]
# X= [[0 67.7142 68.4014 66.8928 67.8542 158168416.0]
#  [1 68.0714 69.2771 67.6071 68.5614 129029425.0]
#  [2 68.5014 68.9114 66.8205 66.8428 151829363.0]
#  ...
#  [1256 30.0 30.64 29.28 29.41 4250786.0]
#  [1257 28.9 30.13 28.65 29.64 3701765.0]
#  [1258 29.57 29.93 28.46 28.53 3800172.0]]
# y= ['AAPL' 'AAPL' 'AAPL' ... 'NFX' 'NFX' 'NFX']

# %%
# Nomalizacion de datos
from sklearn import preprocessing
Xn=preprocessing.normalize(X[:, 0:7])
print(Xn)
# Out:
# [[0.00000000e+00 4.28114548e-07 4.32459284e-07 4.22921350e-07
#   4.28999681e-07 1.00000000e+00]
#  [7.75017016e-09 5.27564933e-07 5.36909314e-07 5.23966529e-07
#   5.31362517e-07 1.00000000e+00]
#  [1.31726825e-08 4.51173598e-07 4.53873998e-07 4.40102617e-07
#   4.40249492e-07 1.00000000e+00]
#  ...
#  [2.95474753e-04 7.05751799e-06 7.20807838e-06 6.88813756e-06
#   6.91872014e-06 9.99999956e-01]
#  [3.39567727e-04 7.80708617e-06 8.13936008e-06 7.73955082e-06
#   8.00699080e-06 9.99999942e-01]
#  [3.31037630e-04 7.78122632e-06 7.87595887e-06 7.48913429e-06
#   7.50755451e-06 9.99999945e-01]]

# %%
""" Estandarización de datos para
aprendizaje automático"""

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(X)
print("x=",X)

print("y=",y)
# Out:
# x= [[-1.77251887 -0.34309189 -0.34313412 -0.34355483 -0.34241447  7.57064512]
#  [-1.769741   -0.34137855 -0.3389633  -0.34010177 -0.33902251  6.06426222]
#  [-1.76696313 -0.33931602 -0.34070507 -0.34390434 -0.34726547  7.24293847]
#  ...
#  [ 1.71648748 -0.52399108 -0.52298571 -0.5253822  -0.52680528 -0.38635266]
#  [ 1.71926535 -0.52926732 -0.52541476 -0.52842774 -0.52570213 -0.41473511]
#  [ 1.72204322 -0.52605361 -0.52636733 -0.52934624 -0.53102605 -0.40964781]]
# y= ['AAPL' 'AAPL' 'AAPL' ... 'NFX' 'NFX' 'NFX']

# %% [markdown]
# # APLICACIÓN DE ALGORITMOS DE MACHINE LEARNING

# %%
#Importacion de librerias
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # DATOS DE ENTRENAMIENTO Y TESTEO

# %%
X_train, X_test, y_train, y_test = train_test_split(Xn, y, test_size=0.2)
print('Son {} datos para entrenamiento y {} datos para prueba'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Son 16823 datos para entrenamiento y 4206 datos para prueba

# %% [markdown]
# # Naive Bayes
#
# Naive Bayes aplica el teorema de Bayes para calcular la probabilidad de que un punto de datos pertenezca a una clase particular. Dada la probabilidad de ciertos valores relacionados, la fórmula para calcular la probabilidad de que ocurra un evento B, dado el evento A, se calcula de la siguiente manera.
# P(B|A) = (P(A|B) * P(B) / P(A))
#
# Esta teoría se considera ingenua, porque asume que no existe dependencia entre ninguna de las características de entrada. Incluso con esta suposición no cierta o ingenua, se ha demostrado que el algoritmo Naive Bayes funciona muy bien en ciertos casos de uso, como los filtros de spam.
#
# El siguiente fragmento de código muestra un ejemplo de cómo crear y predecir un modelo Naive Bayes utilizando las bibliotecas de scikit-learn.

# %%
from sklearn.naive_bayes import MultinomialNB
model_name='Naive Bayes Classifier'
clf=MultinomialNB()
#nb_model= Pipeline(steps=[('preprocessor', preprocessor),('classifier', classifier)])
#Pipeline(steps=[('preprocessor',preprocessorForFeatures),('classifier',nbClassifier)])
clf.fit(X_train,y_train)
MultinomialNB()
y_predict_nb=clf.predict(X_test)
print('Naive Bayes Classifier: {}'.format(clf.score(X_train, y_train)))
print(y_predict_nb)
# Out:
# Naive Bayes Classifier: 0.06146347262676098
# ['FAST' 'FAST' 'FAST' ... 'FAST' 'FAST' 'FAST']

# %% [markdown]
# # Modelo de Regresión Logística
#
# En los Modelos de Regresión Logística (MRL) la ecuación de regresión
# modeliza la relación entre el logaritmo neperiano de los OD y las variables
# explicativas: https://es.wikipedia.org/wiki/Regresi%C3%B3n_log%C3%ADstica

# %%
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Regresión Logística: {}'.format(algoritmo.score(X_train, y_train)))
print(Y_pred)
# Out:
# Precisión Regresión Logística: 0.06146347262676098
# ['FAST' 'FAST' 'FAST' ... 'FAST' 'FAST' 'FAST']

# %% [markdown]
# # Modelo de Máquinas de Vectores de Soporte
#
# SVM es un modelo que representa a los puntos de muestra en el espacio, separando las clases a 2 espacios lo más amplios posibles mediante un hiperplano de separación definido como el vector entre los 2 puntos, de las 2 clases, más cercanos al que se llama vector soporte. Cuando las nuevas muestras se ponen en correspondencia con dicho modelo, en función de los espacios a los que pertenezcan, pueden ser clasificadas a una o la otra clase (https://es.wikipedia.org/wiki/M%C3%A1quinas_de_vectores_de_soporte)
# https://www.cienciadedatos.net/documentos/py24-svm-python.html

# %%
#Modelo de Máquinas de Vectores de Soporte
algoritmo = SVC()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Máquinas de Vectores de Soporte: {}'.format(algoritmo.score(X_train, y_train)))
print(Y_pred)
# Out:
# Precisión Máquinas de Vectores de Soporte: 0.06146347262676098
# ['FAST' 'FAST' 'FAST' ... 'FAST' 'FAST' 'FAST']

# %% [markdown]
#  # Modelo de Vecinos más Cercanos
#  es un método de clasificación supervisada (Aprendizaje, estimación basada en un conjunto de entrenamiento y prototipos) que sirve para estimar la función de densidad **F(x/Cj)** de las predictoras ***x*** por cada clase  **Cj**.
#  https://es.wikipedia.org/wiki/K_vecinos_m%C3%A1s_pr%C3%B3ximos

# %%
#Modelo de Vecinos más Cercanos
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Vecinos más Cercanos: {}'.format(algoritmo.score(X_train, y_train)))
print(Y_pred)
# Out:
# Precisión Vecinos más Cercanos: 0.6466147536111276
# ['FL' 'MYL' 'M' ... 'GM' 'FAST' 'MYL']

# %% [markdown]
# # Modelo de Árboles de Decisión Clasificación
#  Sistema de aprendizaje supervisado que aplica la estrategia "divide y vencerás" para hacer la clasificación, implementando métodos y técnicas para la realización de procesos inteligentes, representando así el conocimiento y el aprendizaje, con el propósito de automatizar tareas.
#  https://es.wikipedia.org/wiki/%C3%81rbol_de_decisi%C3%B3n_(modelo_de_clasificaci%C3%B3n_ID3)

# %%
#Modelo de Árboles de Decisión Clasificación
algoritmo = DecisionTreeClassifier()
algoritmo.fit(X_train, y_train)
Y_pred = algoritmo.predict(X_test)
print('Precisión Árboles de Decisión Clasificación: {}'.format(algoritmo.score(X_train, y_train)))
print(Y_pred)
# Out:
# Precisión Árboles de Decisión Clasificación: 0.8512750401236403
# ['FAST' 'NFX' 'MSI' ... 'GM' 'FAST' 'FL']

# %% [markdown]
# # MLPClassifier
# el modelo perceptrón multicapa (MLP
#
# https://scikit-learn.org/0.23/modules/generated/sklearn.neural_network.MLPClassifier.html?highlight=mlpclassifier#examples-using-sklearn-neural-network-mlpclassifier
#
# https://bookdown.org/content/2274/metodos-de-clasificacion.html#red-neuronal-artificial

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=100, activation='logistic', random_state=1, max_iter=1000).fit(X_train, y_train)
clf.predict_proba(X_test)
Y_pred=clf.predict(X_test)
print('Network Neuronal Clasificación: {}'.format(clf.score(X_train, y_train)))
print(Y_pred)
# Out:
# Network Neuronal Clasificación: 0.749984148119967
# ['NFLX' 'MSFT' 'FOX' ... 'GOOG' 'NFX' 'NFLX']
# /opt/conda/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=0)
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
# El pipeline se puede utilizar como cualquier otro estimador
# y evita que el equipo de prueba se filtre en el tren
pipe.fit(X_train, y_train)
Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC())])
#pipe.score(X_test, y_test)
Y_pred=pipe.predict(X_test)
print('Network Neuronal Clasificación: {}'.format(pipe.score(X_train, y_train)))
print(Y_pred)
# Out:
# Network Neuronal Clasificación: 0.6641937733815231
# ['FB' 'MSFT' 'FAST' ... 'GOOG' 'NFX' 'NFLX']
